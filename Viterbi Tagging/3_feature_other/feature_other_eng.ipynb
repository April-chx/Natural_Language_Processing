# %%
import os
import re
import subprocess
import numpy as np

# %%
tags = [t.strip().split(' ')[-1] for t in list(filter(lambda x:x != '-DOCSTART- -X- -X- O\n',open("../data/conll03/eng.train").readlines())) if len(t.strip().split(' '))>1]
tags = sorted(list(set(tags)))
tags
# Out:
# ['B-LOC', 'B-MISC', 'B-ORG', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'MO', 'O']

# %%
def if_has_W(feature):
    if feature not in W:
        return 0
    else:
        return W[feature]


def Pre_Next(): # ('NN','NN')
    P_tags  =[] 
    for pt in tags:
        tp_P_tags = []
        for nt in tags:
            tp_P_tags.append(if_has_W(('pt '+nt,'t '+pt)))
        P_tags.append(tp_P_tags)
    P_tags = np.asarray(P_tags)
    return P_tags


def hmm_viterbi(W, words):
    y_pred = []
    i= 0
    aug_words = ['__SENTINEL__', '__SENTINEL__'] + words + ['__SENTINEL__', '__SENTINEL__']
    for ppw, pw, w, nw, nnw in zip(aug_words, aug_words[1:], aug_words[2:], aug_words[3:], aug_words[4:]):
        # NOTE: No pt, ppt attribs currently
        attribs = {'ppw ' + ppw,
                   'pw ' + pw,
                   'w ' + w,
                   'nw ' + nw,
                   'nnw ' + nnw,
                   }
        for j in range(1, 5):
            attribs.add('pref ' + w[:j])
            attribs.add('suff ' + w[-j:][::-1])
        if re.search('[0-9]', w):
            attribs.add('dig __NONE__')
        if re.search('[A-Z]', w):
            attribs.add('uc __NONE__')
        if '-' in w:
            attribs.add('hyph __NONE__')
        
        score_list = []
        for tag in tags:
            score = 0
            for a in attribs:
                if (a, tag) in W:
                    score += W[(a, tag)]
            score_list.append(score)
        
        #Viterbi
        if i == 0:
            data = words[i]
            first_level = []
            for tag_number in range(len(tags)):   
                first_level.append((if_has_W(('pt '+'','t '+tag))+score_list[tag_number]))
            y_pred.append(tags[first_level.index(max(first_level))])
            next_value = first_level
        else:
            data = words[i]
            probility = ((next_value + Pre_Next()).T + [score_list[tag_number] for tag_number in range(len(tags))]).T
            y_pred.append(tags[probility.max(axis=1).argmax()])
            next_value = probility.max(axis=1)

        i+=1
    return y_pred

def create_features(words, word_tags):
    loc = 0
    w_temp = {}
    aug_words = ['__SENTINEL__', '__SENTINEL__'] + words + ['__SENTINEL__', '__SENTINEL__']

    for ppw, pw, w, nw, nnw in zip(aug_words, aug_words[1:], aug_words[2:], aug_words[3:], aug_words[4:]):
        # NOTE: No pt, ppt attribs currently
        attribs = {'ppw ' + ppw,
                   'pw ' + pw,
                   'w ' + w,
                   'nw ' + nw,
                   'nnw ' + nnw,
                   }
        for j in range(1, 5):
            attribs.add('pref ' + w[:j])
            attribs.add('suff ' + w[-j:][::-1])
        if re.search('[0-9]', w):
            attribs.add('dig __NONE__')
        if re.search('[A-Z]', w):
            attribs.add('uc __NONE__')
        if '-' in w:
            attribs.add('hyph __NONE__')
        for a in attribs:
            if (a, word_tags[loc]) in w_temp:
                w_temp[(a, word_tags[loc])] += 1
            else: w_temp[(a, word_tags[loc])] = 1
        loc += 1
        
        
    for i in range(len(word_tags)+1):
        if i == 0:
            first_tag = 'pt '+''
        else:
            first_tag = 'pt '+word_tags[i-1]
        
        if i == len(word_tags):
            next_tag = 't '+''
        else:
            next_tag = 't '+word_tags[i]
            
            if (first_tag,next_tag) not in w_temp:
                w_temp[(first_tag,next_tag)] = 0.001#create_trans((tags[i-1],tags[i]))
            else:
                w_temp[(first_tag,next_tag)] += 0.001#create_trans((tags[i-1],tags[i]))

    return w_temp

# %%
text = [t.strip().split(' ') for t in list(filter(lambda x:x != '-DOCSTART- -X- -X- O\n',open("../data/conll03/eng.train").readlines()))]
sen_locs = [t for t in range(len(text)) if len(text[t])==1]
text_train = [[text[s] for s in range(sen_locs[loc]+1,sen_locs[loc+1])] for loc in range(len(sen_locs)-1)]
text_train[:1]
# Out:
# [[['EU', 'NNP', 'I-NP', 'I-ORG'],
#   ['rejects', 'VBZ', 'I-VP', 'O'],
#   ['German', 'JJ', 'I-NP', 'I-MISC'],
#   ['call', 'NN', 'I-NP', 'O'],
#   ['to', 'TO', 'I-VP', 'O'],
#   ['boycott', 'VB', 'I-VP', 'O'],
#   ['British', 'JJ', 'I-NP', 'I-MISC'],
#   ['lamb', 'NN', 'I-NP', 'O'],
#   ['.', '.', 'O', 'O']]]

# %%
text = [t.strip().split(' ') for t in list(filter(lambda x:x != '-DOCSTART- -X- -X- O\n',open("../data/conll03/eng.testa").readlines()))]
sen_locs = [t for t in range(len(text)) if len(text[t])==1]
text_pred = [[text[s] for s in range(sen_locs[loc]+1,sen_locs[loc+1])] for loc in range(len(sen_locs)-1)]
text_pred[:1]
# Out:
# [[['CRICKET', 'NNP', 'I-NP', 'O'],
#   ['-', ':', 'O', 'O'],
#   ['LEICESTERSHIRE', 'NNP', 'I-NP', 'I-ORG'],
#   ['TAKE', 'NNP', 'I-NP', 'O'],
#   ['OVER', 'IN', 'I-PP', 'O'],
#   ['AT', 'NNP', 'I-NP', 'O'],
#   ['TOP', 'NNP', 'I-NP', 'O'],
#   ['AFTER', 'NNP', 'I-NP', 'O'],
#   ['INNINGS', 'NNP', 'I-NP', 'O'],
#   ['VICTORY', 'NN', 'I-NP', 'O'],
#   ['.', '.', 'O', 'O']]]

# %%
W = {}
epoch = 100
for e in range(epoch):
    print('epoch = '+ str(e+1))
    # training
    for sentence in text_train:

        words = [s[0] for s in sentence]
        word_tags = [s[-1] for s in sentence]

        y_pred = hmm_viterbi(W, words)
        w_true = create_features(words, word_tags)
        w_pred = create_features(words, y_pred)
        for wt in w_true:
            if wt in W: W[wt] += w_true[wt]
            else: W[wt] = w_true[wt]

        for wp in w_pred:
            if wp in W: W[wp] -= w_pred[wp]
            else: W[wp] = -w_pred[wp]
                
    # predicting            
    filename = 'result_SPViterbi.txt'
    if os.path.exists(filename):
        os.remove(filename)

    save_wt = '\n'
    for sentence in text_pred:
        words = [s[0] for s in sentence]
        y_pred = hmm_viterbi(W, words)

        for wt in range(len(sentence)):
            save_wt += sentence[wt][0]+' '+sentence[wt][1]+' '+sentence[wt][2]+' '+sentence[wt][3]+' '+y_pred[wt]+'\n'

        save_wt += '\n'

    with open('result_SPViterbi.txt', 'w+') as txt_file:
        txt_file.write(save_wt)

    output = subprocess.run("/usr/bin/perl -w conlleval < result_SPViterbi.txt", shell=True, stdout=subprocess.PIPE, universal_newlines=True)
    print('\n'+output.stdout)
# Out:
# epoch = 1
#
# processed 51362 tokens with 5942 phrases; found: 6760 phrases; correct: 4286.
# accuracy:  94.88%; precision:  63.40%; recall:  72.13%; FB1:  67.49
#               LOC: precision:  80.20%; recall:  68.81%; FB1:  74.07
#              MISC: precision:  67.53%; recall:  73.75%; FB1:  70.50
#               ORG: precision:  47.34%; recall:  50.48%; FB1:  48.86
#               PER: precision:  60.61%; recall:  90.39%; FB1:  72.56
#
# epoch = 2
#
# processed 51362 tokens with 5942 phrases; found: 6200 phrases; correct: 4513.
# accuracy:  96.12%; precision:  72.79%; recall:  75.95%; FB1:  74.34
#               LOC: precision:  82.33%; recall:  80.68%; FB1:  81.50
#              MISC: precision:  69.63%; recall:  70.61%; FB1:  70.11
#               ORG: precision:  57.03%; recall:  62.34%; FB1:  59.57
#               PER: precision:  77.24%; recall:  83.82%; FB1:  80.40
#
# epoch = 3
#
# processed 51362 tokens with 5942 phrases; found: 6396 phrases; correct: 4632.
# accuracy:  96.28%; precision:  72.42%; recall:  77.95%; FB1:  75.09
#               LOC: precision:  85.32%; recall:  78.77%; FB1:  81.91
#              MISC: precision:  61.54%; recall:  81.24%; FB1:  70.03
#               ORG: precision:  58.53%; recall:  59.58%; FB1:  59.05
#               PER: precision:  77.29%; recall:  88.87%; FB1:  82.68
#
# epoch = 4
#
# processed 51362 tokens with 5942 phrases; found: 6442 phrases; correct: 4769.
# accuracy:  96.57%; precision:  74.03%; recall:  80.26%; FB1:  77.02
#               LOC: precision:  79.88%; recall:  89.06%; FB1:  84.22
#              MISC: precision:  60.84%; recall:  83.41%; FB1:  70.36
#               ORG: precision:  67.64%; recall:  55.48%; FB1:  60.96
#               PER: precision:  79.80%; recall:  87.95%; FB1:  83.68
#
# epoch = 5
#
# processed 51362 tokens with 5942 phrases; found: 6080 phrases; correct: 4741.
# accuracy:  96.84%; precision:  77.98%; recall:  79.79%; FB1:  78.87
#               LOC: precision:  83.06%; recall:  85.68%; FB1:  84.35
#              MISC: precision:  72.99%; recall:  83.51%; FB1:  77.90
#               ORG: precision:  69.63%; recall:  60.18%; FB1:  64.56
#               PER: precision:  80.67%; recall:  86.32%; FB1:  83.40
#
# epoch = 6
#
# processed 51362 tokens with 5942 phrases; found: 6285 phrases; correct: 4656.
# accuracy:  96.46%; precision:  74.08%; recall:  78.36%; FB1:  76.16
#               LOC: precision:  84.22%; recall:  84.54%; FB1:  84.38
#              MISC: precision:  62.13%; recall:  84.71%; FB1:  71.68
#               ORG: precision:  62.91%; recall:  69.05%; FB1:  65.84
#               PER: precision:  81.54%; recall:  75.79%; FB1:  78.56
#
# epoch = 7
#
# processed 51362 tokens with 5942 phrases; found: 6208 phrases; correct: 4841.
# accuracy:  96.94%; precision:  77.98%; recall:  81.47%; FB1:  79.69
#               LOC: precision:  86.08%; recall:  86.50%; FB1:  86.29
#              MISC: precision:  70.26%; recall:  82.75%; FB1:  76.00
#               ORG: precision:  67.15%; recall:  65.70%; FB1:  66.42
#               PER: precision:  81.87%; recall:  87.30%; FB1:  84.50
#
# epoch = 8
#
# processed 51362 tokens with 5942 phrases; found: 6184 phrases; correct: 4879.
# accuracy:  96.98%; precision:  78.90%; recall:  82.11%; FB1:  80.47
#               LOC: precision:  78.73%; recall:  92.71%; FB1:  85.15
#              MISC: precision:  80.30%; recall:  82.65%; FB1:  81.45
#               ORG: precision:  71.57%; recall:  62.71%; FB1:  66.85
#               PER: precision:  82.92%; recall:  85.40%; FB1:  84.14
#
# epoch = 9
#
# processed 51362 tokens with 5942 phrases; found: 6081 phrases; correct: 4706.
# accuracy:  96.76%; precision:  77.39%; recall:  79.20%; FB1:  78.28
#               LOC: precision:  83.46%; recall:  86.50%; FB1:  84.95
#              MISC: precision:  72.80%; recall:  82.43%; FB1:  77.31
#               ORG: precision:  66.14%; recall:  65.10%; FB1:  65.61
#               PER: precision:  81.85%; recall:  80.56%; FB1:  81.20
#
# epoch = 10
#
# processed 51362 tokens with 5942 phrases; found: 5882 phrases; correct: 4713.
# accuracy:  96.87%; precision:  80.13%; recall:  79.32%; FB1:  79.72
#               LOC: precision:  84.19%; recall:  86.06%; FB1:  85.11
#              MISC: precision:  79.24%; recall:  79.50%; FB1:  79.37
#               ORG: precision:  71.00%; recall:  68.08%; FB1:  69.51
#               PER: precision:  82.88%; recall:  80.67%; FB1:  81.76
#
# epoch = 11
#
# processed 51362 tokens with 5942 phrases; found: 5979 phrases; correct: 4792.
# accuracy:  97.07%; precision:  80.15%; recall:  80.65%; FB1:  80.40
#               LOC: precision:  86.02%; recall:  86.77%; FB1:  86.40
#              MISC: precision:  84.19%; recall:  78.52%; FB1:  81.26
#               ORG: precision:  66.97%; recall:  70.92%; FB1:  68.89
#               PER: precision:  82.50%; recall:  82.68%; FB1:  82.59
#
# epoch = 12
#
# processed 51362 tokens with 5942 phrases; found: 5950 phrases; correct: 4736.
# accuracy:  96.88%; precision:  79.60%; recall:  79.70%; FB1:  79.65
#               LOC: precision:  83.68%; recall:  86.83%; FB1:  85.23
#              MISC: precision:  79.45%; recall:  82.21%; FB1:  80.81
#               ORG: precision:  69.17%; recall:  67.93%; FB1:  68.55
#               PER: precision:  83.02%; recall:  79.91%; FB1:  81.44
#
# epoch = 13
#
# processed 51362 tokens with 5942 phrases; found: 5976 phrases; correct: 4846.
# accuracy:  97.15%; precision:  81.09%; recall:  81.56%; FB1:  81.32
#               LOC: precision:  86.08%; recall:  87.21%; FB1:  86.64
#              MISC: precision:  78.18%; recall:  83.95%; FB1:  80.96
#               ORG: precision:  72.12%; recall:  68.08%; FB1:  70.04
#               PER: precision:  83.75%; recall:  84.53%; FB1:  84.14
#
# epoch = 14
#
# processed 51362 tokens with 5942 phrases; found: 6060 phrases; correct: 4781.
# accuracy:  97.02%; precision:  78.89%; recall:  80.46%; FB1:  79.67
#               LOC: precision:  85.88%; recall:  86.39%; FB1:  86.13
#              MISC: precision:  78.54%; recall:  81.78%; FB1:  80.13
#               ORG: precision:  66.95%; recall:  76.29%; FB1:  71.31
#               PER: precision:  82.19%; recall:  76.93%; FB1:  79.47
#
# epoch = 15
#
# processed 51362 tokens with 5942 phrases; found: 6091 phrases; correct: 4910.
# accuracy:  97.28%; precision:  80.61%; recall:  82.63%; FB1:  81.61
#               LOC: precision:  85.94%; recall:  89.17%; FB1:  87.52
#              MISC: precision:  74.61%; recall:  83.84%; FB1:  78.96
#               ORG: precision:  73.46%; recall:  71.81%; FB1:  72.62
#               PER: precision:  83.57%; recall:  83.39%; FB1:  83.48
#
# epoch = 16
#
# processed 51362 tokens with 5942 phrases; found: 5974 phrases; correct: 4887.
# accuracy:  97.17%; precision:  81.80%; recall:  82.25%; FB1:  82.02
#               LOC: precision:  84.88%; recall:  87.10%; FB1:  85.98
#              MISC: precision:  77.40%; recall:  84.71%; FB1:  80.89
#               ORG: precision:  78.47%; recall:  67.41%; FB1:  72.52
#               PER: precision:  83.09%; recall:  86.97%; FB1:  84.99
#
# epoch = 17
#
# processed 51362 tokens with 5942 phrases; found: 5891 phrases; correct: 4823.
# accuracy:  97.10%; precision:  81.87%; recall:  81.17%; FB1:  81.52
#               LOC: precision:  86.24%; recall:  86.66%; FB1:  86.45
#              MISC: precision:  76.66%; recall:  83.73%; FB1:  80.04
#               ORG: precision:  77.77%; recall:  69.13%; FB1:  73.19
#               PER: precision:  82.99%; recall:  83.17%; FB1:  83.08
#
# epoch = 18
#
# processed 51362 tokens with 5942 phrases; found: 6080 phrases; correct: 4922.
# accuracy:  97.29%; precision:  80.95%; recall:  82.83%; FB1:  81.88
#               LOC: precision:  87.10%; recall:  88.57%; FB1:  87.83
#              MISC: precision:  74.21%; recall:  83.62%; FB1:  78.63
#               ORG: precision:  74.44%; recall:  71.89%; FB1:  73.14
#               PER: precision:  83.07%; recall:  84.69%; FB1:  83.87
#
# epoch = 19
#
# processed 51362 tokens with 5942 phrases; found: 6105 phrases; correct: 4986.
# accuracy:  97.39%; precision:  81.67%; recall:  83.91%; FB1:  82.78
#               LOC: precision:  85.22%; recall:  87.92%; FB1:  86.55
#              MISC: precision:  78.87%; recall:  84.60%; FB1:  81.63
#               ORG: precision:  75.41%; recall:  75.24%; FB1:  75.33
#               PER: precision:  84.01%; recall:  85.88%; FB1:  84.94
#
# epoch = 20
#
# processed 51362 tokens with 5942 phrases; found: 6043 phrases; correct: 4795.
# accuracy:  97.01%; precision:  79.35%; recall:  80.70%; FB1:  80.02
#               LOC: precision:  87.54%; recall:  83.02%; FB1:  85.22
#              MISC: precision:  83.44%; recall:  81.45%; FB1:  82.44
#               ORG: precision:  64.79%; recall:  79.87%; FB1:  71.54
#               PER: precision:  82.84%; recall:  78.61%; FB1:  80.67
#
# epoch = 21
#
# processed 51362 tokens with 5942 phrases; found: 6083 phrases; correct: 4935.
# accuracy:  97.31%; precision:  81.13%; recall:  83.05%; FB1:  82.08
#               LOC: precision:  85.26%; recall:  86.94%; FB1:  86.09
#              MISC: precision:  79.48%; recall:  83.62%; FB1:  81.50
#               ORG: precision:  72.37%; recall:  76.96%; FB1:  74.59
#               PER: precision:  84.62%; recall:  83.33%; FB1:  83.97
#
# epoch = 22
#
# processed 51362 tokens with 5942 phrases; found: 5948 phrases; correct: 4874.
# accuracy:  97.28%; precision:  81.94%; recall:  82.03%; FB1:  81.98
#               LOC: precision:  88.00%; recall:  84.21%; FB1:  86.06
#              MISC: precision:  82.98%; recall:  81.45%; FB1:  82.21
#               ORG: precision:  71.71%; recall:  77.11%; FB1:  74.31
#               PER: precision:  83.67%; recall:  83.71%; FB1:  83.69
#
# epoch = 23
#
# processed 51362 tokens with 5942 phrases; found: 6048 phrases; correct: 4989.
# accuracy:  97.43%; precision:  82.49%; recall:  83.96%; FB1:  83.22
#               LOC: precision:  86.63%; recall:  86.77%; FB1:  86.70
#              MISC: precision:  78.39%; recall:  84.60%; FB1:  81.38
#               ORG: precision:  78.59%; recall:  73.90%; FB1:  76.17
#               PER: precision:  83.20%; recall:  88.17%; FB1:  85.61
#
# epoch = 24
#
# processed 51362 tokens with 5942 phrases; found: 6081 phrases; correct: 4983.
# accuracy:  97.41%; precision:  81.94%; recall:  83.86%; FB1:  82.89
#               LOC: precision:  90.56%; recall:  85.14%; FB1:  87.77
#              MISC: precision:  73.34%; recall:  85.03%; FB1:  78.75
#               ORG: precision:  75.65%; recall:  74.12%; FB1:  74.88
#               PER: precision:  83.26%; recall:  89.09%; FB1:  86.07
#
# epoch = 25
#
# processed 51362 tokens with 5942 phrases; found: 6100 phrases; correct: 4976.
# accuracy:  97.40%; precision:  81.57%; recall:  83.74%; FB1:  82.64
#               LOC: precision:  86.46%; recall:  87.97%; FB1:  87.21
#              MISC: precision:  83.32%; recall:  82.86%; FB1:  83.09
#               ORG: precision:  70.86%; recall:  78.15%; FB1:  74.33
#               PER: precision:  84.36%; recall:  84.04%; FB1:  84.20
#
# epoch = 26
#
# processed 51362 tokens with 5942 phrases; found: 5993 phrases; correct: 4888.
# accuracy:  97.22%; precision:  81.56%; recall:  82.26%; FB1:  81.91
#               LOC: precision:  87.78%; recall:  85.63%; FB1:  86.69
#              MISC: precision:  83.52%; recall:  82.43%; FB1:  82.97
#               ORG: precision:  69.24%; recall:  78.23%; FB1:  73.46
#               PER: precision:  84.80%; recall:  81.76%; FB1:  83.25
#
# epoch = 27
#
# processed 51362 tokens with 5942 phrases; found: 6195 phrases; correct: 5010.
# accuracy:  97.42%; precision:  80.87%; recall:  84.32%; FB1:  82.56
#               LOC: precision:  82.44%; recall:  91.51%; FB1:  86.74
#              MISC: precision:  79.59%; recall:  83.30%; FB1:  81.40
#               ORG: precision:  74.92%; recall:  74.42%; FB1:  74.67
#               PER: precision:  84.08%; recall:  84.85%; FB1:  84.46
#
# epoch = 28
#
# processed 51362 tokens with 5942 phrases; found: 6151 phrases; correct: 4932.
# accuracy:  97.23%; precision:  80.18%; recall:  83.00%; FB1:  81.57
#               LOC: precision:  78.41%; recall:  94.12%; FB1:  85.55
#              MISC: precision:  79.13%; recall:  83.08%; FB1:  81.06
#               ORG: precision:  78.13%; recall:  71.66%; FB1:  74.76
#               PER: precision:  84.44%; recall:  80.13%; FB1:  82.23
#
# epoch = 29
#
# processed 51362 tokens with 5942 phrases; found: 6136 phrases; correct: 5002.
# accuracy:  97.40%; precision:  81.52%; recall:  84.18%; FB1:  82.83
#               LOC: precision:  87.25%; recall:  86.06%; FB1:  86.65
#              MISC: precision:  74.08%; recall:  84.92%; FB1:  79.13
#               ORG: precision:  75.09%; recall:  74.65%; FB1:  74.87
#               PER: precision:  84.64%; recall:  88.87%; FB1:  86.71
#
# epoch = 30
#
# processed 51362 tokens with 5942 phrases; found: 5996 phrases; correct: 4959.
# accuracy:  97.38%; precision:  82.71%; recall:  83.46%; FB1:  83.08
#               LOC: precision:  88.38%; recall:  86.99%; FB1:  87.68
#              MISC: precision:  81.47%; recall:  82.97%; FB1:  82.21
#               ORG: precision:  72.97%; recall:  77.93%; FB1:  75.37
#               PER: precision:  85.36%; recall:  84.20%; FB1:  84.78
#
# epoch = 31
#
# processed 51362 tokens with 5942 phrases; found: 5985 phrases; correct: 4937.
# accuracy:  97.35%; precision:  82.49%; recall:  83.09%; FB1:  82.79
#               LOC: precision:  83.53%; recall:  89.71%; FB1:  86.51
#              MISC: precision:  85.75%; recall:  80.91%; FB1:  83.26
#               ORG: precision:  76.61%; recall:  75.24%; FB1:  75.92
#               PER: precision:  84.05%; recall:  83.28%; FB1:  83.67
#
# epoch = 32
#
# processed 51362 tokens with 5942 phrases; found: 5891 phrases; correct: 4920.
# accuracy:  97.33%; precision:  83.52%; recall:  82.80%; FB1:  83.16
#               LOC: precision:  89.85%; recall:  83.40%; FB1:  86.50
#              MISC: precision:  83.39%; recall:  81.13%; FB1:  82.24
#               ORG: precision:  74.59%; recall:  77.26%; FB1:  75.90
#               PER: precision:  84.42%; recall:  87.08%; FB1:  85.73
#
# epoch = 33
#
# processed 51362 tokens with 5942 phrases; found: 6010 phrases; correct: 4933.
# accuracy:  97.35%; precision:  82.08%; recall:  83.02%; FB1:  82.55
#               LOC: precision:  89.30%; recall:  81.82%; FB1:  85.40
#              MISC: precision:  79.77%; recall:  82.97%; FB1:  81.34
#               ORG: precision:  72.52%; recall:  77.55%; FB1:  74.95
#               PER: precision:  84.02%; recall:  88.22%; FB1:  86.07
#
# epoch = 34
#
# processed 51362 tokens with 5942 phrases; found: 6001 phrases; correct: 4912.
# accuracy:  97.33%; precision:  81.85%; recall:  82.67%; FB1:  82.26
#               LOC: precision:  87.81%; recall:  83.56%; FB1:  85.63
#              MISC: precision:  78.48%; recall:  82.65%; FB1:  80.51
#               ORG: precision:  73.45%; recall:  76.73%; FB1:  75.05
#               PER: precision:  84.32%; recall:  86.10%; FB1:  85.20
#
# epoch = 35
#
# processed 51362 tokens with 5942 phrases; found: 5958 phrases; correct: 4951.
# accuracy:  97.42%; precision:  83.10%; recall:  83.32%; FB1:  83.21
#               LOC: precision:  87.35%; recall:  87.59%; FB1:  87.47
#              MISC: precision:  81.57%; recall:  82.10%; FB1:  81.84
#               ORG: precision:  75.56%; recall:  75.17%; FB1:  75.36
#               PER: precision:  85.06%; recall:  85.61%; FB1:  85.34
#
# epoch = 36
#
# processed 51362 tokens with 5942 phrases; found: 6150 phrases; correct: 4996.
# accuracy:  97.42%; precision:  81.24%; recall:  84.08%; FB1:  82.63
#               LOC: precision:  86.63%; recall:  85.74%; FB1:  86.18
#              MISC: precision:  80.33%; recall:  83.30%; FB1:  81.79
#               ORG: precision:  70.26%; recall:  78.75%; FB1:  74.26
#               PER: precision:  85.26%; recall:  86.70%; FB1:  85.98
#
# epoch = 37
#
# processed 51362 tokens with 5942 phrases; found: 5956 phrases; correct: 4911.
# accuracy:  97.31%; precision:  82.45%; recall:  82.65%; FB1:  82.55
#               LOC: precision:  88.90%; recall:  82.80%; FB1:  85.74
#              MISC: precision:  80.64%; recall:  82.21%; FB1:  81.42
#               ORG: precision:  73.25%; recall:  78.23%; FB1:  75.66
#               PER: precision:  84.52%; recall:  85.94%; FB1:  85.22
#
# epoch = 38
#
# processed 51362 tokens with 5942 phrases; found: 5877 phrases; correct: 4913.
# accuracy:  97.34%; precision:  83.60%; recall:  82.68%; FB1:  83.14
#               LOC: precision:  88.37%; recall:  86.45%; FB1:  87.40
#              MISC: precision:  85.02%; recall:  79.39%; FB1:  82.11
#               ORG: precision:  75.06%; recall:  76.29%; FB1:  75.67
#               PER: precision:  84.59%; recall:  85.23%; FB1:  84.91
#
# epoch = 39
#
# processed 51362 tokens with 5942 phrases; found: 5769 phrases; correct: 4791.
# accuracy:  97.06%; precision:  83.05%; recall:  80.63%; FB1:  81.82
#               LOC: precision:  88.31%; recall:  81.00%; FB1:  84.50
#              MISC: precision:  81.68%; recall:  81.24%; FB1:  81.46
#               ORG: precision:  75.72%; recall:  74.20%; FB1:  74.95
#               PER: precision:  84.13%; recall:  84.64%; FB1:  84.38
#
# epoch = 40
#
# processed 51362 tokens with 5942 phrases; found: 5969 phrases; correct: 4877.
# accuracy:  97.25%; precision:  81.71%; recall:  82.08%; FB1:  81.89
#               LOC: precision:  87.74%; recall:  85.36%; FB1:  86.53
#              MISC: precision:  77.72%; recall:  82.86%; FB1:  80.21
#               ORG: precision:  72.49%; recall:  76.44%; FB1:  74.41
#               PER: precision:  85.15%; recall:  82.52%; FB1:  83.82
#
# epoch = 41
#
# processed 51362 tokens with 5942 phrases; found: 5985 phrases; correct: 4931.
# accuracy:  97.36%; precision:  82.39%; recall:  82.99%; FB1:  82.69
#               LOC: precision:  89.19%; recall:  85.36%; FB1:  87.23
#              MISC: precision:  79.56%; recall:  82.75%; FB1:  81.13
#               ORG: precision:  72.82%; recall:  77.33%; FB1:  75.01
#               PER: precision:  84.76%; recall:  84.85%; FB1:  84.81
#
# epoch = 42
#
# processed 51362 tokens with 5942 phrases; found: 5835 phrases; correct: 4884.
# accuracy:  97.28%; precision:  83.70%; recall:  82.19%; FB1:  82.94
#               LOC: precision:  89.40%; recall:  84.49%; FB1:  86.87
#              MISC: precision:  83.45%; recall:  80.37%; FB1:  81.88
#               ORG: precision:  75.15%; recall:  76.44%; FB1:  75.79
#               PER: precision:  84.79%; recall:  85.02%; FB1:  84.90
#
# epoch = 43
#
# processed 51362 tokens with 5942 phrases; found: 5941 phrases; correct: 4936.
# accuracy:  97.37%; precision:  83.08%; recall:  83.07%; FB1:  83.08
#               LOC: precision:  87.23%; recall:  86.61%; FB1:  86.92
#              MISC: precision:  81.71%; recall:  82.86%; FB1:  82.28
#               ORG: precision:  75.88%; recall:  73.90%; FB1:  74.88
#               PER: precision:  84.75%; recall:  86.32%; FB1:  85.53
#
# epoch = 44
#
# processed 51362 tokens with 5942 phrases; found: 5881 phrases; correct: 4868.
# accuracy:  97.27%; precision:  82.78%; recall:  81.93%; FB1:  82.35
#               LOC: precision:  87.19%; recall:  86.72%; FB1:  86.95
#              MISC: precision:  83.54%; recall:  81.45%; FB1:  82.48
#               ORG: precision:  74.31%; recall:  73.97%; FB1:  74.14
#               PER: precision:  84.18%; recall:  83.17%; FB1:  83.67
#
# epoch = 45
#
# processed 51362 tokens with 5942 phrases; found: 6016 phrases; correct: 4969.
# accuracy:  97.42%; precision:  82.60%; recall:  83.63%; FB1:  83.11
#               LOC: precision:  86.98%; recall:  85.47%; FB1:  86.22
#              MISC: precision:  81.10%; recall:  82.86%; FB1:  81.97
#               ORG: precision:  75.55%; recall:  74.87%; FB1:  75.21
#               PER: precision:  84.07%; recall:  88.55%; FB1:  86.25
#
# epoch = 46
#
# processed 51362 tokens with 5942 phrases; found: 5867 phrases; correct: 4832.
# accuracy:  97.15%; precision:  82.36%; recall:  81.32%; FB1:  81.84
#               LOC: precision:  87.18%; recall:  82.91%; FB1:  84.99
#              MISC: precision:  80.34%; recall:  82.86%; FB1:  81.58
#               ORG: precision:  76.64%; recall:  69.50%; FB1:  72.90
#               PER: precision:  82.59%; recall:  87.57%; FB1:  85.01
#
# epoch = 47
#
# processed 51362 tokens with 5942 phrases; found: 6137 phrases; correct: 4966.
# accuracy:  97.37%; precision:  80.92%; recall:  83.57%; FB1:  82.23
#               LOC: precision:  86.96%; recall:  84.59%; FB1:  85.76
#              MISC: precision:  75.76%; recall:  83.73%; FB1:  79.55
#               ORG: precision:  72.53%; recall:  77.18%; FB1:  74.78
#               PER: precision:  84.30%; recall:  87.13%; FB1:  85.69
#
# epoch = 48
#
# processed 51362 tokens with 5942 phrases; found: 5968 phrases; correct: 4997.
# accuracy:  97.49%; precision:  83.73%; recall:  84.10%; FB1:  83.91
#               LOC: precision:  89.73%; recall:  86.12%; FB1:  87.89
#              MISC: precision:  83.57%; recall:  83.30%; FB1:  83.43
#               ORG: precision:  76.65%; recall:  76.14%; FB1:  76.39
#               PER: precision:  83.21%; recall:  88.27%; FB1:  85.67
#
# epoch = 49
#
# processed 51362 tokens with 5942 phrases; found: 6037 phrases; correct: 4926.
# accuracy:  97.31%; precision:  81.60%; recall:  82.90%; FB1:  82.24
#               LOC: precision:  85.51%; recall:  87.37%; FB1:  86.43
#              MISC: precision:  78.33%; recall:  83.51%; FB1:  80.84
#               ORG: precision:  75.26%; recall:  75.54%; FB1:  75.40
#               PER: precision:  84.00%; recall:  83.50%; FB1:  83.75
#
# epoch = 50
#
# processed 51362 tokens with 5942 phrases; found: 5991 phrases; correct: 4817.
# accuracy:  97.10%; precision:  80.40%; recall:  81.07%; FB1:  80.73
#               LOC: precision:  82.05%; recall:  88.84%; FB1:  85.31
#              MISC: precision:  81.00%; recall:  82.32%; FB1:  81.66
#               ORG: precision:  73.18%; recall:  73.45%; FB1:  73.32
#               PER: precision:  83.83%; recall:  78.23%; FB1:  80.93
#
# epoch = 51
#
# processed 51362 tokens with 5942 phrases; found: 5949 phrases; correct: 4828.
# accuracy:  97.17%; precision:  81.16%; recall:  81.25%; FB1:  81.20
#               LOC: precision:  86.15%; recall:  84.32%; FB1:  85.23
#              MISC: precision:  79.85%; recall:  82.97%; FB1:  81.38
#               ORG: precision:  72.30%; recall:  77.26%; FB1:  74.69
#               PER: precision:  83.98%; recall:  80.24%; FB1:  82.07
#
# epoch = 52
#
# processed 51362 tokens with 5942 phrases; found: 6010 phrases; correct: 4942.
# accuracy:  97.34%; precision:  82.23%; recall:  83.17%; FB1:  82.70
#               LOC: precision:  84.67%; recall:  88.41%; FB1:  86.50
#              MISC: precision:  80.34%; recall:  82.43%; FB1:  81.37
#               ORG: precision:  76.98%; recall:  75.32%; FB1:  76.14
#               PER: precision:  84.41%; recall:  84.04%; FB1:  84.22
#
# epoch = 53
#
# processed 51362 tokens with 5942 phrases; found: 6034 phrases; correct: 4981.
# accuracy:  97.45%; precision:  82.55%; recall:  83.83%; FB1:  83.18
#               LOC: precision:  88.51%; recall:  85.08%; FB1:  86.76
#              MISC: precision:  82.40%; recall:  81.78%; FB1:  82.09
#               ORG: precision:  74.04%; recall:  77.63%; FB1:  75.79
#               PER: precision:  83.36%; recall:  88.11%; FB1:  85.67
#
# epoch = 54
#
# processed 51362 tokens with 5942 phrases; found: 6108 phrases; correct: 4944.
# accuracy:  97.34%; precision:  80.94%; recall:  83.20%; FB1:  82.06
#               LOC: precision:  85.60%; recall:  88.35%; FB1:  86.95
#              MISC: precision:  81.01%; recall:  81.45%; FB1:  81.23
#               ORG: precision:  70.49%; recall:  78.00%; FB1:  74.05
#               PER: precision:  84.62%; recall:  82.74%; FB1:  83.67
#
# epoch = 55
#
# processed 51362 tokens with 5942 phrases; found: 6050 phrases; correct: 5022.
# accuracy:  97.49%; precision:  83.01%; recall:  84.52%; FB1:  83.76
#               LOC: precision:  86.53%; recall:  88.13%; FB1:  87.32
#              MISC: precision:  84.82%; recall:  81.24%; FB1:  82.99
#               ORG: precision:  74.46%; recall:  77.63%; FB1:  76.01
#               PER: precision:  84.98%; recall:  87.57%; FB1:  86.26
#
# epoch = 56
#
# processed 51362 tokens with 5942 phrases; found: 5991 phrases; correct: 4920.
# accuracy:  97.33%; precision:  82.12%; recall:  82.80%; FB1:  82.46
#               LOC: precision:  86.60%; recall:  85.14%; FB1:  85.86
#              MISC: precision:  83.50%; recall:  81.24%; FB1:  82.35
#               ORG: precision:  72.16%; recall:  77.70%; FB1:  74.83
#               PER: precision:  84.87%; recall:  84.96%; FB1:  84.92
#
# epoch = 57
#
# processed 51362 tokens with 5942 phrases; found: 6033 phrases; correct: 4967.
# accuracy:  97.40%; precision:  82.33%; recall:  83.59%; FB1:  82.96
#               LOC: precision:  87.01%; recall:  87.15%; FB1:  87.08
#              MISC: precision:  81.76%; recall:  82.65%; FB1:  82.20
#               ORG: precision:  73.36%; recall:  78.45%; FB1:  75.82
#               PER: precision:  84.95%; recall:  84.26%; FB1:  84.60
#
# epoch = 58
#
# processed 51362 tokens with 5942 phrases; found: 6015 phrases; correct: 5019.
# accuracy:  97.49%; precision:  83.44%; recall:  84.47%; FB1:  83.95
#               LOC: precision:  88.23%; recall:  87.75%; FB1:  87.99
#              MISC: precision:  84.76%; recall:  81.45%; FB1:  83.08
#               ORG: precision:  75.02%; recall:  77.48%; FB1:  76.23
#               PER: precision:  84.35%; recall:  87.79%; FB1:  86.03
#
# epoch = 59
#
# processed 51362 tokens with 5942 phrases; found: 6067 phrases; correct: 4991.
# accuracy:  97.41%; precision:  82.26%; recall:  84.00%; FB1:  83.12
#               LOC: precision:  88.98%; recall:  85.25%; FB1:  87.07
#              MISC: precision:  81.14%; recall:  83.08%; FB1:  82.10
#               ORG: precision:  71.25%; recall:  79.27%; FB1:  75.04
#               PER: precision:  85.30%; recall:  86.64%; FB1:  85.97
#
# epoch = 60
#
# processed 51362 tokens with 5942 phrases; found: 6050 phrases; correct: 5018.
# accuracy:  97.47%; precision:  82.94%; recall:  84.45%; FB1:  83.69
#               LOC: precision:  88.86%; recall:  86.83%; FB1:  87.83
#              MISC: precision:  81.92%; recall:  82.54%; FB1:  82.23
#               ORG: precision:  74.13%; recall:  79.27%; FB1:  76.61
#               PER: precision:  84.51%; recall:  86.81%; FB1:  85.65
#
# epoch = 61
#
# processed 51362 tokens with 5942 phrases; found: 6148 phrases; correct: 4993.
# accuracy:  97.40%; precision:  81.21%; recall:  84.03%; FB1:  82.60
#               LOC: precision:  88.19%; recall:  86.17%; FB1:  87.17
#              MISC: precision:  78.78%; recall:  82.97%; FB1:  80.82
#               ORG: precision:  70.28%; recall:  79.19%; FB1:  74.47
#               PER: precision:  84.61%; recall:  85.94%; FB1:  85.27
#
# epoch = 62
#
# processed 51362 tokens with 5942 phrases; found: 6033 phrases; correct: 5027.
# accuracy:  97.54%; precision:  83.33%; recall:  84.60%; FB1:  83.96
#               LOC: precision:  87.21%; recall:  88.68%; FB1:  87.94
#              MISC: precision:  82.88%; recall:  82.43%; FB1:  82.65
#               ORG: precision:  76.77%; recall:  76.88%; FB1:  76.83
#               PER: precision:  84.36%; recall:  87.24%; FB1:  85.78
#
# epoch = 63
#
# processed 51362 tokens with 5942 phrases; found: 5939 phrases; correct: 4953.
# accuracy:  97.41%; precision:  83.40%; recall:  83.36%; FB1:  83.38
#               LOC: precision:  89.32%; recall:  86.50%; FB1:  87.89
#              MISC: precision:  80.11%; recall:  82.10%; FB1:  81.09
#               ORG: precision:  76.95%; recall:  75.17%; FB1:  76.05
#               PER: precision:  83.94%; recall:  86.81%; FB1:  85.35
#
# epoch = 64
#
# processed 51362 tokens with 5942 phrases; found: 5988 phrases; correct: 4994.
# accuracy:  97.44%; precision:  83.40%; recall:  84.05%; FB1:  83.72
#               LOC: precision:  87.29%; recall:  87.86%; FB1:  87.57
#              MISC: precision:  84.84%; recall:  81.34%; FB1:  83.06
#               ORG: precision:  76.74%; recall:  75.54%; FB1:  76.14
#               PER: precision:  83.57%; recall:  87.79%; FB1:  85.62
#
# epoch = 65
#
# processed 51362 tokens with 5942 phrases; found: 5875 phrases; correct: 4923.
# accuracy:  97.35%; precision:  83.80%; recall:  82.85%; FB1:  83.32
#               LOC: precision:  89.08%; recall:  86.55%; FB1:  87.80
#              MISC: precision:  84.80%; recall:  80.48%; FB1:  82.58
#               ORG: precision:  75.66%; recall:  75.32%; FB1:  75.49
#               PER: precision:  84.10%; recall:  85.83%; FB1:  84.95
#
# epoch = 66
#
# processed 51362 tokens with 5942 phrases; found: 5997 phrases; correct: 5010.
# accuracy:  97.50%; precision:  83.54%; recall:  84.32%; FB1:  83.93
#               LOC: precision:  88.50%; recall:  87.59%; FB1:  88.04
#              MISC: precision:  82.39%; recall:  82.21%; FB1:  82.30
#               ORG: precision:  76.09%; recall:  78.08%; FB1:  77.07
#               PER: precision:  84.76%; recall:  86.64%; FB1:  85.69
#
# epoch = 67
#
# processed 51362 tokens with 5942 phrases; found: 5903 phrases; correct: 4953.
# accuracy:  97.40%; precision:  83.91%; recall:  83.36%; FB1:  83.63
#               LOC: precision:  90.37%; recall:  84.81%; FB1:  87.50
#              MISC: precision:  83.30%; recall:  81.67%; FB1:  82.48
#               ORG: precision:  75.09%; recall:  77.78%; FB1:  76.41
#               PER: precision:  84.78%; recall:  86.81%; FB1:  85.78
#
# epoch = 68
#
# processed 51362 tokens with 5942 phrases; found: 6030 phrases; correct: 5011.
# accuracy:  97.49%; precision:  83.10%; recall:  84.33%; FB1:  83.71
#               LOC: precision:  88.99%; recall:  87.15%; FB1:  88.06
#              MISC: precision:  80.76%; recall:  82.86%; FB1:  81.80
#               ORG: precision:  74.70%; recall:  77.93%; FB1:  76.28
#               PER: precision:  84.89%; recall:  86.92%; FB1:  85.89
#
# epoch = 69
#
# processed 51362 tokens with 5942 phrases; found: 6095 phrases; correct: 5049.
# accuracy:  97.53%; precision:  82.84%; recall:  84.97%; FB1:  83.89
#               LOC: precision:  87.37%; recall:  88.89%; FB1:  88.13
#              MISC: precision:  78.63%; recall:  83.41%; FB1:  80.95
#               ORG: precision:  77.90%; recall:  76.51%; FB1:  77.20
#               PER: precision:  83.95%; recall:  88.00%; FB1:  85.93
#
# epoch = 70
#
# processed 51362 tokens with 5942 phrases; found: 5992 phrases; correct: 4993.
# accuracy:  97.45%; precision:  83.33%; recall:  84.03%; FB1:  83.68
#               LOC: precision:  87.12%; recall:  87.64%; FB1:  87.38
#              MISC: precision:  82.16%; recall:  82.43%; FB1:  82.30
#               ORG: precision:  77.39%; recall:  75.32%; FB1:  76.34
#               PER: precision:  84.27%; recall:  87.57%; FB1:  85.89
#
# epoch = 71
#
# processed 51362 tokens with 5942 phrases; found: 6077 phrases; correct: 5035.
# accuracy:  97.54%; precision:  82.85%; recall:  84.74%; FB1:  83.78
#               LOC: precision:  88.06%; recall:  87.10%; FB1:  87.58
#              MISC: precision:  78.97%; recall:  83.51%; FB1:  81.18
#               ORG: precision:  76.28%; recall:  77.48%; FB1:  76.88
#               PER: precision:  84.56%; recall:  88.27%; FB1:  86.37
#
# epoch = 72
#
# processed 51362 tokens with 5942 phrases; found: 5913 phrases; correct: 4948.
# accuracy:  97.39%; precision:  83.68%; recall:  83.27%; FB1:  83.48
#               LOC: precision:  87.62%; recall:  87.86%; FB1:  87.74
#              MISC: precision:  82.30%; recall:  81.67%; FB1:  81.98
#               ORG: precision:  78.05%; recall:  75.32%; FB1:  76.66
#               PER: precision:  84.37%; recall:  85.29%; FB1:  84.83
#
# epoch = 73
#
# processed 51362 tokens with 5942 phrases; found: 6052 phrases; correct: 5046.
# accuracy:  97.53%; precision:  83.38%; recall:  84.92%; FB1:  84.14
#               LOC: precision:  87.83%; recall:  88.41%; FB1:  88.12
#              MISC: precision:  83.33%; recall:  81.34%; FB1:  82.33
#               ORG: precision:  76.85%; recall:  77.48%; FB1:  77.16
#               PER: precision:  83.70%; recall:  88.65%; FB1:  86.11
#
# epoch = 74
#
# processed 51362 tokens with 5942 phrases; found: 5989 phrases; correct: 4976.
# accuracy:  97.46%; precision:  83.09%; recall:  83.74%; FB1:  83.41
#               LOC: precision:  86.91%; recall:  88.19%; FB1:  87.54
#              MISC: precision:  82.35%; recall:  81.45%; FB1:  81.90
#               ORG: precision:  76.66%; recall:  75.91%; FB1:  76.28
#               PER: precision:  84.19%; recall:  86.16%; FB1:  85.16
#
# epoch = 75
#
# processed 51362 tokens with 5942 phrases; found: 6056 phrases; correct: 5037.
# accuracy:  97.54%; precision:  83.17%; recall:  84.77%; FB1:  83.96
#               LOC: precision:  86.43%; recall:  89.77%; FB1:  88.06
#              MISC: precision:  83.08%; recall:  82.54%; FB1:  82.81
#               ORG: precision:  77.84%; recall:  75.17%; FB1:  76.48
#               PER: precision:  83.58%; recall:  87.89%; FB1:  85.68
#
# epoch = 76
#
# processed 51362 tokens with 5942 phrases; found: 6019 phrases; correct: 4969.
# accuracy:  97.46%; precision:  82.56%; recall:  83.63%; FB1:  83.09
#               LOC: precision:  88.26%; recall:  87.21%; FB1:  87.73
#              MISC: precision:  80.98%; recall:  82.21%; FB1:  81.59
#               ORG: precision:  73.71%; recall:  77.55%; FB1:  75.58
#               PER: precision:  84.49%; recall:  85.18%; FB1:  84.83
#
# epoch = 77
#
# processed 51362 tokens with 5942 phrases; found: 6031 phrases; correct: 4994.
# accuracy:  97.48%; precision:  82.81%; recall:  84.05%; FB1:  83.42
#               LOC: precision:  87.83%; recall:  87.59%; FB1:  87.71
#              MISC: precision:  83.37%; recall:  81.56%; FB1:  82.46
#               ORG: precision:  74.70%; recall:  75.32%; FB1:  75.01
#               PER: precision:  83.44%; recall:  88.11%; FB1:  85.71
#
# epoch = 78
#
# processed 51362 tokens with 5942 phrases; found: 6072 phrases; correct: 5049.
# accuracy:  97.57%; precision:  83.15%; recall:  84.97%; FB1:  84.05
#               LOC: precision:  86.96%; recall:  90.75%; FB1:  88.81
#              MISC: precision:  83.19%; recall:  81.56%; FB1:  82.37
#               ORG: precision:  77.43%; recall:  74.20%; FB1:  75.78
#               PER: precision:  83.16%; recall:  88.76%; FB1:  85.87
#
# epoch = 79
#
# processed 51362 tokens with 5942 phrases; found: 5937 phrases; correct: 4978.
# accuracy:  97.48%; precision:  83.85%; recall:  83.78%; FB1:  83.81
#               LOC: precision:  88.06%; recall:  87.92%; FB1:  87.99
#              MISC: precision:  82.17%; recall:  82.00%; FB1:  82.08
#               ORG: precision:  79.51%; recall:  72.63%; FB1:  75.92
#               PER: precision:  83.40%; recall:  88.65%; FB1:  85.95
#
# epoch = 80
#
# processed 51362 tokens with 5942 phrases; found: 6049 phrases; correct: 5004.
# accuracy:  97.48%; precision:  82.72%; recall:  84.21%; FB1:  83.46
#               LOC: precision:  88.47%; recall:  87.26%; FB1:  87.86
#              MISC: precision:  79.48%; recall:  82.75%; FB1:  81.08
#               ORG: precision:  74.80%; recall:  76.81%; FB1:  75.79
#               PER: precision:  84.63%; recall:  87.30%; FB1:  85.94
#
# epoch = 81
#
# processed 51362 tokens with 5942 phrases; found: 5964 phrases; correct: 4943.
# accuracy:  97.39%; precision:  82.88%; recall:  83.19%; FB1:  83.03
#               LOC: precision:  89.73%; recall:  85.14%; FB1:  87.37
#              MISC: precision:  78.56%; recall:  83.08%; FB1:  80.76
#               ORG: precision:  76.28%; recall:  75.76%; FB1:  76.02
#               PER: precision:  83.44%; recall:  86.70%; FB1:  85.04
#
# epoch = 82
#
# processed 51362 tokens with 5942 phrases; found: 6080 phrases; correct: 5024.
# accuracy:  97.51%; precision:  82.63%; recall:  84.55%; FB1:  83.58
#               LOC: precision:  88.33%; recall:  87.37%; FB1:  87.85
#              MISC: precision:  81.65%; recall:  82.54%; FB1:  82.09
#               ORG: precision:  73.46%; recall:  79.05%; FB1:  76.15
#               PER: precision:  84.64%; recall:  86.75%; FB1:  85.68
#
# epoch = 83
#
# processed 51362 tokens with 5942 phrases; found: 6013 phrases; correct: 4974.
# accuracy:  97.45%; precision:  82.72%; recall:  83.71%; FB1:  83.21
#               LOC: precision:  87.46%; recall:  88.08%; FB1:  87.77
#              MISC: precision:  78.32%; recall:  83.08%; FB1:  80.63
#               ORG: precision:  78.10%; recall:  73.68%; FB1:  75.83
#               PER: precision:  83.44%; recall:  86.97%; FB1:  85.17
#
# epoch = 84
#
# processed 51362 tokens with 5942 phrases; found: 5999 phrases; correct: 4987.
# accuracy:  97.48%; precision:  83.13%; recall:  83.93%; FB1:  83.53
#               LOC: precision:  89.18%; recall:  86.17%; FB1:  87.65
#              MISC: precision:  79.31%; recall:  82.75%; FB1:  81.00
#               ORG: precision:  76.47%; recall:  75.84%; FB1:  76.15
#               PER: precision:  84.06%; recall:  88.17%; FB1:  86.06
#
# epoch = 85
#
# processed 51362 tokens with 5942 phrases; found: 5971 phrases; correct: 4985.
# accuracy:  97.47%; precision:  83.49%; recall:  83.89%; FB1:  83.69
#               LOC: precision:  89.98%; recall:  85.52%; FB1:  87.69
#              MISC: precision:  81.72%; recall:  83.41%; FB1:  82.56
#               ORG: precision:  75.63%; recall:  76.58%; FB1:  76.10
#               PER: precision:  84.01%; recall:  87.84%; FB1:  85.88
#
# epoch = 86
#
# processed 51362 tokens with 5942 phrases; found: 6067 phrases; correct: 5011.
# accuracy:  97.49%; precision:  82.59%; recall:  84.33%; FB1:  83.45
#               LOC: precision:  88.63%; recall:  88.24%; FB1:  88.43
#              MISC: precision:  81.95%; recall:  82.75%; FB1:  82.35
#               ORG: precision:  72.32%; recall:  78.52%; FB1:  75.29
#               PER: precision:  85.04%; recall:  85.45%; FB1:  85.24
#
# epoch = 87
#
# processed 51362 tokens with 5942 phrases; found: 6025 phrases; correct: 4959.
# accuracy:  97.39%; precision:  82.31%; recall:  83.46%; FB1:  82.88
#               LOC: precision:  89.16%; recall:  86.88%; FB1:  88.01
#              MISC: precision:  80.53%; recall:  82.97%; FB1:  81.73
#               ORG: precision:  71.53%; recall:  79.27%; FB1:  75.20
#               PER: precision:  85.33%; recall:  83.33%; FB1:  84.32
#
# epoch = 88
#
# processed 51362 tokens with 5942 phrases; found: 5968 phrases; correct: 5019.
# accuracy:  97.52%; precision:  84.10%; recall:  84.47%; FB1:  84.28
#               LOC: precision:  89.53%; recall:  86.55%; FB1:  88.02
#              MISC: precision:  84.06%; recall:  81.78%; FB1:  82.90
#               ORG: precision:  78.04%; recall:  75.54%; FB1:  76.77
#               PER: precision:  83.22%; recall:  90.23%; FB1:  86.59
#
# epoch = 89
#
# processed 51362 tokens with 5942 phrases; found: 5927 phrases; correct: 4942.
# accuracy:  97.39%; precision:  83.38%; recall:  83.17%; FB1:  83.28
#               LOC: precision:  89.25%; recall:  85.85%; FB1:  87.51
#              MISC: precision:  81.80%; recall:  82.86%; FB1:  82.33
#               ORG: precision:  75.22%; recall:  75.39%; FB1:  75.31
#               PER: precision:  84.48%; recall:  86.32%; FB1:  85.39
#
# epoch = 90
#
# processed 51362 tokens with 5942 phrases; found: 6042 phrases; correct: 5021.
# accuracy:  97.52%; precision:  83.10%; recall:  84.50%; FB1:  83.80
#               LOC: precision:  89.07%; recall:  88.30%; FB1:  88.68
#              MISC: precision:  79.02%; recall:  84.16%; FB1:  81.51
#               ORG: precision:  76.13%; recall:  76.81%; FB1:  76.47
#               PER: precision:  84.46%; recall:  86.48%; FB1:  85.46
#
# epoch = 91
#
# processed 51362 tokens with 5942 phrases; found: 6116 phrases; correct: 4979.
# accuracy:  97.39%; precision:  81.41%; recall:  83.79%; FB1:  82.58
#               LOC: precision:  88.57%; recall:  86.45%; FB1:  87.49
#              MISC: precision:  78.48%; recall:  82.65%; FB1:  80.51
#               ORG: precision:  70.34%; recall:  79.57%; FB1:  74.67
#               PER: precision:  85.12%; recall:  84.80%; FB1:  84.96
#
# epoch = 92
#
# processed 51362 tokens with 5942 phrases; found: 5975 phrases; correct: 4945.
# accuracy:  97.37%; precision:  82.76%; recall:  83.22%; FB1:  82.99
#               LOC: precision:  90.37%; recall:  85.79%; FB1:  88.02
#              MISC: precision:  82.48%; recall:  81.67%; FB1:  82.07
#               ORG: precision:  71.54%; recall:  79.12%; FB1:  75.14
#               PER: precision:  84.74%; recall:  84.42%; FB1:  84.58
#
# epoch = 93
#
# processed 51362 tokens with 5942 phrases; found: 6033 phrases; correct: 4993.
# accuracy:  97.47%; precision:  82.76%; recall:  84.03%; FB1:  83.39
#               LOC: precision:  88.80%; recall:  88.08%; FB1:  88.44
#              MISC: precision:  78.44%; recall:  81.67%; FB1:  80.02
#               ORG: precision:  75.80%; recall:  75.91%; FB1:  75.86
#               PER: precision:  84.07%; recall:  87.08%; FB1:  85.55
#
# epoch = 94
#
# processed 51362 tokens with 5942 phrases; found: 6109 phrases; correct: 5013.
# accuracy:  97.46%; precision:  82.06%; recall:  84.37%; FB1:  83.20
#               LOC: precision:  89.62%; recall:  87.86%; FB1:  88.73
#              MISC: precision:  81.23%; recall:  81.67%; FB1:  81.45
#               ORG: precision:  70.67%; recall:  79.94%; FB1:  75.02
#               PER: precision:  84.44%; recall:  85.45%; FB1:  84.94
#
# epoch = 95
#
# processed 51362 tokens with 5942 phrases; found: 6063 phrases; correct: 4962.
# accuracy:  97.38%; precision:  81.84%; recall:  83.51%; FB1:  82.67
#               LOC: precision:  88.52%; recall:  84.81%; FB1:  86.63
#              MISC: precision:  84.18%; recall:  81.34%; FB1:  82.74
#               ORG: precision:  69.62%; recall:  79.64%; FB1:  74.30
#               PER: precision:  84.45%; recall:  86.10%; FB1:  85.27
#
# epoch = 96
#
# processed 51362 tokens with 5942 phrases; found: 6055 phrases; correct: 4990.
# accuracy:  97.46%; precision:  82.41%; recall:  83.98%; FB1:  83.19
#               LOC: precision:  88.38%; recall:  85.68%; FB1:  87.01
#              MISC: precision:  81.81%; recall:  82.43%; FB1:  82.12
#               ORG: precision:  72.62%; recall:  78.52%; FB1:  75.46
#               PER: precision:  84.59%; recall:  87.02%; FB1:  85.79
#
# epoch = 97
#
# processed 51362 tokens with 5942 phrases; found: 6043 phrases; correct: 4987.
# accuracy:  97.45%; precision:  82.53%; recall:  83.93%; FB1:  83.22
#               LOC: precision:  87.38%; recall:  88.19%; FB1:  87.78
#              MISC: precision:  77.21%; recall:  84.16%; FB1:  80.54
#               ORG: precision:  77.29%; recall:  74.87%; FB1:  76.06
#               PER: precision:  84.19%; recall:  86.16%; FB1:  85.16
#
# epoch = 98
#
# processed 51362 tokens with 5942 phrases; found: 6011 phrases; correct: 4970.
# accuracy:  97.42%; precision:  82.68%; recall:  83.64%; FB1:  83.16
#               LOC: precision:  87.29%; recall:  88.95%; FB1:  88.11
#              MISC: precision:  81.36%; recall:  82.86%; FB1:  82.11
#               ORG: precision:  75.64%; recall:  76.88%; FB1:  76.26
#               PER: precision:  83.89%; recall:  83.66%; FB1:  83.77
#
# epoch = 99
#
# processed 51362 tokens with 5942 phrases; found: 6050 phrases; correct: 5038.
# accuracy:  97.54%; precision:  83.27%; recall:  84.79%; FB1:  84.02
#               LOC: precision:  86.72%; recall:  90.26%; FB1:  88.45
#              MISC: precision:  82.97%; recall:  82.43%; FB1:  82.70
#               ORG: precision:  77.91%; recall:  75.99%; FB1:  76.93
#               PER: precision:  83.65%; recall:  86.92%; FB1:  85.25
#
# epoch = 100
#
# processed 51362 tokens with 5942 phrases; found: 6057 phrases; correct: 5037.
# accuracy:  97.50%; precision:  83.16%; recall:  84.77%; FB1:  83.96
#               LOC: precision:  86.86%; recall:  89.28%; FB1:  88.05
#              MISC: precision:  81.67%; recall:  82.65%; FB1:  82.16
#               ORG: precision:  78.83%; recall:  74.42%; FB1:  76.56
#               PER: precision:  83.10%; recall:  88.87%; FB1:  85.89
